# %%
import subprocess
import os
import json
from typing import Dict
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
def validate_path(path):
    if not os.path.exists(path):
        raise FileNotFoundError(f"File not found: {path}")
    
def validate_data(data : Dict):
    validate_path(data['robots'])
    validate_path(data['objects'])
    validate_path(data['scene'])
    validate_path(data['obstacles'])

    print("SUCCESS")

# %%
directory = "/home/alex/multitask/24-data-gen/in/shelf"
folders = [item for item in os.listdir(directory) if os.path.isdir(os.path.join(directory, item))]
print(f"Папки {len(folders)}:", folders)
# Out:
# Папки 933: ['1933', '703', '1178', '2299', '1376', '1231', '5041', '3706', '413', '3219', '4927', '930', '1393', '3780', '3459', '1294', '2737', '498', '632', '3195', '2616', '4047', '312', '2662', '3170', '654', '3921', '190', '3389', '1417', '3866', '3275', '4016', '2015', '3543', '1194', '2175', '2914', '2326', '2136', '4704', '4355', '1080', '1334', '1452', '2898', '3763', '1013', '3101', '4212', '2198', '2724', '172', '3735', '1182', '2579', '4028', '1027', '827', '2022', '162', '620', '4055', '3058', '3744', '1481', '4991', '1911', '2107', '4115', '1578', '3821', '1891', '4696', '295', '2083', '3183', '1252', '1745', '198', '2673', '1970', '1335', '4287', '1738', '4768', '3614', '2008', '871', '2212', '3581', '2325', '4764', '4361', '3695', '2959', '432', '5129', '3233', '1708', '399', '1648', '1556', '3391', '1168', '2203', '509', '1239', '4688', '3536', '1292', '2972', '3405', '1865', '5057', '3387', '477', '3503', '1467', '3670', '4906', '345', '3444', '1506', '2624', '3249', '2029', '2845', '1687', '2040', '771', '3634', '2242', '4043', '1818', '2195', '519', '1770', '1915', '196', '3623', '2263', '4923', '3366', '1848', '1244', '959', '3976', '3684', '3055', '4219', '2395', '4903', '4598', '566', '225', '488', '2469', '3285', '221', '5134', '758', '616', '1135', '4749', '1496', '1837', '4101', '4299', '1736', '4845', '3047', '1797', '4074', '1529', '4966', '3228', '4283', '4504', '55', '1199', '2707', '1298', '135', '3610', '4277', '3809', '4147', '836', '2978', '3523', '5049', '4786', '1381', '1730', '1163', '113', '781', '2804', '4902', '377', '2314', '4970', '2167', '4860', '4321', '1858', '3524', '1875', '2721', '1712', '2774', '217', '405', '683', '4140', '3828', '3235', '1225', '4944', '434', '2094', '1577', '7', '553', '45', '5012', '88', '4263', '565', '2740', '560', '3551', '4332', '4350', '625', '2514', '2843', '3036', '332', '4671', '4882', '4544', '4618', '98', '374', '326', '2864', '1816', '2910', '4046', '554', '1301', '2565', '1216', '3176', '3276', '1053', '1172', '4334', '1248', '4873', '1127', '274', '4447', '714', '989', '985', '3587', '2098', '3352', '3952', '1383', '4635', '2477', '722', '1052', '1843', '2543', '3903', '940', '5084', '2166', '3413', '521', '3803', '891', '4616', '622', '4338', '1953', '1959', '5061', '2000', '2348', '2681', '3305', '1323', '1112', '108', '4253', '1550', '3178', '4565', '3163', '3074', '2644', '2306', '1366', '4478', '2708', '718', '2967', '612', '2051', '5113', '2558', '14', '3638', '3856', '3529', '4586', '512', '115', '2397', '4190', '2626', '3120', '3726', '543', '2942', '296', '1431', '1580', '2284', '702', '3123', '2824', '2126', '4545', '2699', '1526', '1332', '1129', '627', '4762', '5031', '2926', '1171', '694', '3105', '3909', '2446', '1189', '3039', '2696', '4404', '785', '2245', '4152', '1229', '2630', '878', '4603', '1737', '3797', '983', '3644', '1510', '2902', '3905', '4223', '4915', '1996', '4582', '1836', '1975', '911', '3014', '5163', '3711', '3326', '275', '3991', '4425', '3113', '229', '4193', '1672', '3547', '4690', '2802', '4053', '4293', '2801', '2993', '1799', '4630', '3722', '536', '3457', '4885', '2989', '3619', '873', '2308', '1921', '1690', '2209', '4020', '3083', '1425', '158', '2374', '180', '1881', '3393', '4238', '286', '4951', '607', '77', '923', '1084', '4097', '4449', '3671', '4534', '2742', '3356', '4131', '1165', '1346', '532', '2075', '4891', '168', '665', '2730', '2034', '851', '510', '2868', '4851', '3034', '2363', '1514', '2494', '2241', '3461', '2551', '1653', '2776', '3792', '649', '1071', '600', '1158', '3187', '828', '540', '2603', '3063', '4148', '4806', '2533', '147', '804', '1215', '5180', '4090', '418', '3147', '2583', '4503', '3657', '2658', '1892', '3561', '925', '428', '5', '5164', '3027', '3364', '1387', '1955', '716', '496', '4699', '4295', '372', '1614', '4793', '580', '1966', '5075', '4466', '2819', '1983', '3450', '693', '3251', '837', '4480', '1500', '2729', '3533', '2189', '756', '2042', '4176', '597', '18 ...

# %%
directory = "/home/alex/multitask/24-data-gen/in/random"
folders = [item for item in os.listdir(directory) if os.path.isdir(os.path.join(directory, item))]
print(f"Папки {len(folders)}:", folders)
# Out:
# Папки 260: ['2717', '5602', '3500', '433', '8100', '3219', '366', '3921', '1583', '5757', '6848', '2914', '280', '7962', '1285', '4441', '9756', '8612', '1182', '4729', '123', '5626', '7285', '943', '9541', '4592', '9901', '7101', '7508', '8731', '8604', '924', '5064', '6927', '7758', '4153', '1686', '6766', '8220', '7778', '566', '2511', '5917', '6303', '1764', '8438', '8371', '3228', '1488', '135', '264', '781', '9330', '4860', '1858', '6507', '8946', '6841', '224', '8905', '2740', '9380', '7337', '5759', '5518', '6875', '2334', '6007', '8877', '2770', '7974', '1539', '5951', '8298', '7438', '5684', '3939', '3100', '6164', '6042', '7019', '3123', '9149', '6322', '7095', '3692', '5359', '1753', '2245', '7865', '983', '3566', '2290', '7492', '9443', '1122', '8124', '4072', '6397', '2754', '2308', '7195', '6154', '817', '5870', '8744', '3546', '8176', '5238', '5679', '8445', '1682', '1158', '3640', '5631', '8796', '5756', '496', '820', '7476', '3793', '8631', '9633', '7993', '6009', '7776', '5071', '7664', '9216', '6187', '3944', '4643', '6159', '8461', '801', '6183', '8234', '502', '2891', '844', '8127', '9865', '209', '4721', '2516', '1762', '0', '9437', '2927', '791', '8153', '2907', '8433', '7335', '2294', '4353', '7725', '370', '6398', '5899', '8782', '7801', '5284', '4463', '3934', '9221', '5846', '8765', '1344', '3222', '8430', '368', '4443', '1461', '4732', '3038', '3859', '979', '1903', '4809', '3668', '5597', '6417', '4249', '8813', '373', '6240', '3377', '3439', '8609', '9071', '6378', '1349', '9883', '1371', '973', '2', '5111', '6941', '6831', '2184', '6028', '5682', '6863', '5892', '7649', '8509', '2796', '686', '3495', '4492', '4490', '5748', '5600', '667', '7014', '3563', '4470', '6604', '3410', '6589', '2433', '3411', '364', '8635', '4437', '1487', '2726', '9299', '7376', '3539', '499', '5439', '6834', '4992', '8528', '1385', '7545', '4063', '6393', '6693', '581', '8440', '8779', '2633', '2566', '9886', '4070', '2063', '7024', '8010', '8378', '9851', '3386', '971', '5753', '9297', '9634', '6005', '4717']

# %%
directory = "/home/alex/multitask/24-data-gen/in/conveyor/"
folders = [item for item in os.listdir(directory) if os.path.isdir(os.path.join(directory, item))]
print(f"Папки {len(folders)}:", folders)
# Out:
# Папки 0: []

# %%
shelf_stats = {}
shelf_stats['2'] = {}
shelf_stats['3'] = {}
shelf_stats['4'] = {}
for key in shelf_stats.keys():
    shelf_stats[key]['travel_time'] = []
    shelf_stats[key]['path_length'] = []
    shelf_stats[key]['total_rrt_time'] = []
    shelf_stats[key]['total_coll_time'] = []
    shelf_stats[key]['total_nn_time'] = []

# %%
folders
# Out:
# ['2717',
#  '5602',
#  '3500',
#  '433',
#  '8100',
#  '3219',
#  '366',
#  '3921',
#  '1583',
#  '5757',
#  '6848',
#  '2914',
#  '280',
#  '7962',
#  '1285',
#  '4441',
#  '9756',
#  '8612',
#  '1182',
#  '4729',
#  '123',
#  '5626',
#  '7285',
#  '943',
#  '9541',
#  '4592',
#  '9901',
#  '7101',
#  '7508',
#  '8731',
#  '8604',
#  '924',
#  '5064',
#  '6927',
#  '7758',
#  '4153',
#  '1686',
#  '6766',
#  '8220',
#  '7778',
#  '566',
#  '2511',
#  '5917',
#  '6303',
#  '1764',
#  '8438',
#  '8371',
#  '3228',
#  '1488',
#  '135',
#  '264',
#  '781',
#  '9330',
#  '4860',
#  '1858',
#  '6507',
#  '8946',
#  '6841',
#  '224',
#  '8905',
#  '2740',
#  '9380',
#  '7337',
#  '5759',
#  '5518',
#  '6875',
#  '2334',
#  '6007',
#  '8877',
#  '2770',
#  '7974',
#  '1539',
#  '5951',
#  '8298',
#  '7438',
#  '5684',
#  '3939',
#  '3100',
#  '6164',
#  '6042',
#  '7019',
#  '3123',
#  '9149',
#  '6322',
#  '7095',
#  '3692',
#  '5359',
#  '1753',
#  '2245',
#  '7865',
#  '983',
#  '3566',
#  '2290',
#  '7492',
#  '9443',
#  '1122',
#  '8124',
#  '4072',
#  '6397',
#  '2754',
#  '2308',
#  '7195',
#  '6154',
#  '817',
#  '5870',
#  '8744',
#  '3546',
#  '8176',
#  '5238',
#  '5679',
#  '8445',
#  '1682',
#  '1158',
#  '3640',
#  '5631',
#  '8796',
#  '5756',
#  '496',
#  '820',
#  '7476',
#  '3793',
#  '8631',
#  '9633',
#  '7993',
#  '6009',
#  '7776',
#  '5071',
#  '7664',
#  '9216',
#  '6187',
#  '3944',
#  '4643',
#  '6159',
#  '8461',
#  '801',
#  '6183',
#  '8234',
#  '502',
#  '2891',
#  '844',
#  '8127',
#  '9865',
#  '209',
#  '4721',
#  '2516',
#  '1762',
#  '0',
#  '9437',
#  '2927',
#  '791',
#  '8153',
#  '2907',
#  '8433',
#  '7335',
#  '2294',
#  '4353',
#  '7725',
#  '370',
#  '6398',
#  '5899',
#  '8782',
#  '7801',
#  '5284',
#  '4463',
#  '3934',
#  '9221',
#  '5846',
#  '8765',
#  '1344',
#  '3222',
#  '8430',
#  '368',
#  '4443',
#  '1461',
#  '4732',
#  '3038',
#  '3859',
#  '979',
#  '1903',
#  '4809',
#  '3668',
#  '5597',
#  '6417',
#  '4249',
#  '8813',
#  '373',
#  '6240',
#  '3377',
#  '3439',
#  '8609',
#  '9071',
#  '6378',
#  '1349',
#  '9883',
#  '1371',
#  '973',
#  '2',
#  '5111',
#  '6941',
#  '6831',
#  '2184',
#  '6028',
#  '5682',
#  '6863',
#  '5892',
#  '7649',
#  '8509',
#  '2796',
#  '686',
#  '3495',
#  '4492',
#  '4490',
#  '5748',
#  '5600',
#  '667',
#  '7014',
#  '3563',
#  '4470',
#  '6604',
#  '3410',
#  '6589',
#  '2433',
#  '3411',
#  '364',
#  '8635',
#  '4437',
#  '1487',
#  '2726',
#  '9299',
#  '7376',
#  '3539',
#  '499',
#  '5439',
#  '6834',
#  '4992',
#  '8528',
#  '1385',
#  '7545',
#  '4063',
#  '6393',
#  '6693',
#  '581',
#  '8440',
#  '8779',
#  '2633',
#  '2566',
#  '9886',
#  '4070',
#  '2063',
#  '7024',
#  '8010',
#  '8378',
#  '9851',
#  '3386',
#  '971',
#  '5753',
#  '9297',
#  '9634',
#  '6005',
#  '4717']

# %%
def clear_dir(directory):
    for filename in os.listdir(directory):
            file_path = os.path.join(directory, filename)
            if os.path.isfile(file_path):
                os.remove(file_path)
                print(f"Deleted: {file_path}")

def get_num_obj(directory):
     with open(directory, 'r') as f:
        data = json.load(f)
        return len(data['objects'])

# %%
def merge_robot_results(input_dir, output_file):
    """
    Объединяет все JSON-файлы из input_dir в один файл output_file.
    Каждый файл должен содержать данные одного робота.
    """
    merged_data = []

    # Перебираем все файлы в директории
    for filename in os.listdir(input_dir):
        if filename.endswith(".json"):
            file_path = os.path.join(input_dir, filename)
            try:
                with open(file_path, "r", encoding="utf-8") as f:
                    data = json.load(f)
                    if data['success'] == 1:
                        merged_data.append(data)
            except Exception as e:
                print(f"Ошибка при чтении файла {filename}: {e}")

    # Сохраняем объединённые данные
    try:
        with open(output_file, "w", encoding="utf-8") as f:
            json.dump(merged_data, f, indent=4, ensure_ascii=False)
        print(f"Объединённый файл сохранён: {output_file}")
    except Exception as e:
        print(f"Ошибка при сохранении файла: {e}")

# Пример использования
input_directory = "/home/alex/multitask/24-data-gen/log"
output_filename = "/home/alex/multitask/24-data-gen/result.json"
merge_robot_results(input_directory, output_filename)

def sort_data(input_file, output_file):
    with open(input_file, "r", encoding="utf-8") as f:
        data = json.load(f)

    robot_dict = {}

    for entry in data:
        robot_name = entry["name"]
        if robot_name not in robot_dict:
            robot_dict[robot_name] = []
        robot_dict[robot_name].append(entry)

    for robot in robot_dict:
        robot_dict[robot].sort(key=lambda x: x["start_time"])

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(robot_dict, f, indent=4, ensure_ascii=False)
# Out:
# Объединённый файл сохранён: /home/alex/multitask/24-data-gen/result.json

# %%
scene = 'random'

directory = "/home/alex/multitask/24-data-gen/log"

seeds = [879, 1, 325, 16, 615]
for folder in tqdm(folders):
    num_objects = get_num_obj(f'/home/alex/multitask/24-data-gen/in/{scene}/{folder}/obj_path.json')    
    for seed in seeds:
        

        args = { 'robots':    f'in/{scene}/{folder}/robot_path.json',
                  'objects':   f'in/{scene}/{folder}/obj_path.json',
                  'scene':     f'in/{scene}/{folder}/scene.g',
                  'obstacles': f'in/{scene}/{folder}/obstacles_file.json'}

        command = [
            './sipp.exe',
            '-pnp',             'true',
            '-mode',            'random_search',
            '-seed',            str(seed),
            '-robot_path',      args['robots'],
            '-obj_path',        args['objects'],
            '-attempt_komo',    'false',
            '-display',         'false',
            '-export_images',   'false',
            #'-scene_path',      args['scene'],
            #'-obstacle_path',   args['obstacles']
        ]
        # validate_data(args)

        clear_dir(directory)
        subprocess.run(command)
        merge_robot_results("/home/alex/multitask/24-data-gen/log", "/home/alex/multitask/24-data-gen/result.json")
        sort_data("/home/alex/multitask/24-data-gen/result.json", f"/home/alex/multitask/24-data-gen/stats_random/sipp_{folder}.json")
        

        command = [
            './sipp.exe',
            '-pnp',             'true',
            '-mode',            'random_search',
            '-seed',            str(seed),
            '-robot_path',      args['robots'],
            '-obj_path',        args['objects'],
            '-attempt_komo',    'false',
            '-display',         'false',
            '-export_images',   'false',
            '-scene_path',      args['scene'],
            '-obstacle_path',   args['obstacles']
        ]
        clear_dir(directory)
        subprocess.run(command)   
        merge_robot_results("/home/alex/multitask/24-data-gen/log", "/home/alex/multitask/24-data-gen/result.json")
        sort_data("/home/alex/multitask/24-data-gen/result.json", f"/home/alex/multitask/24-data-gen/stats_random/rrt_{folder}.json")
# Out:
#   0%|          | 0/260 [00:00<?, ?it/s]
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023602_974.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023603_234.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023608_549.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023605_119.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023606_590.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023602_566.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023606_204.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023607_417.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023603_864.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023607_968.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023607_171.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023604_338.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023607_702.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023606_435.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023605_687.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023602_742.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023608_239.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023604_612.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023606_765.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_023606_962.json
# ** INFO:util.cpp:initCmdLine:596(1) ** cmd line arguments: './sipp.exe -pnp true -mode random_search -seed 879 -robot_path in/random/2717/robot_path.json -obj_path in/random/2717/obj_path.json -attempt_komo false -display false -export_images false'
# ** INFO:util.cpp:initCmdLine:600(1) ** run path: '/home/alex/multitask/24-data-gen'
# ** INFO:graph.cpp:initParameters:1359(1) ** parsed parameters:
# {pnp,
# mode:"random_search",
# seed:879,
# robot_path:"in/random/2717/robot_path.json",
# obj_path:"in/random/2717/obj_path.json",
# attempt_komo!,
# display!,
# export_images!,
# display!,
# export_images!,
# early_stopping,
# objects:5,
# vmax:0.1,
# smoothing,
# attempt_komo!}
#
# ** WARNING:switch.cpp:conv_times2tuples:38(-1) beyond the time!: endTime=5 phases=2
# ** WARNING:switch.cpp:conv_times2tuples:38(-1) beyond the time!: endTime=5 phases=2
# t0 0
# t_up 95
# РАЗМЕРНОСТЬ 6
# start:[0, 0.5, -1.2, 0, 1.57, 1.57] time: 0
# goal:[0.59292, -0.441263, -1.37433, 0.168734, 1.437, 1.08742] time: 95
# -6.2832 6.2832
# -2 0.75
# -3.1416 3.1416
# -3.2832 3.2832
# -3.2832 3.2832
# -6.2832 6.2832
# 1 1 1
# МЫ НАШЛИ РЕШЕНИЕ, МЫ НАШЛИ ЕГО
# NODES IN SOLUTION: 3
# ====================================================
# time: 0, [0, 0.5, -1.2, 0, 1.57, 1.57]
# time: 10, [0.390977, 0.109533, -1.25976, -0.247576, 1.2116, 2.27807]
# time: 24.1487, [0.59292, -0.441263, -1.37433, 0.168734, 1.437, 1.08742]
# [0, 10, 24.1487]
# 0x7ffc28d489b8 3 6 0
# [0, 0.5, -1.2, 0, 1.57, 1.57,
#  0.390977, 0.109533, -1.25976, -0.247576, 1.2116, 2.27807,
#  0.59292, -0.441263, -1.37433, 0.168734, 1.437, 1.08742]
# Путь робота записан в файл robot_path_20250611_034258_250.json
# t <= time(0)
# t: 0
# time(0): 0
# t >= time(time.d0-1)
# t: 25
# time(time.d0-1): 24.1487
# t <= time(0)
# t: 0
# time(0): 0
# t >= time(time.d0-1)
# t: 25
# time(time.d0-1): 25
# t <= time(0)
# t: 0
# time(0): 0
# t >= time(time.d0-1)
# t: 25
# time(time.d0-1): 25
# t0 25
# t_up 132
# РАЗМЕРНОСТЬ 6
# start:[0.59292, -0.441263, -1.37433, 0.168734, 1.437, 1.08742] time: 25
# goal:[-0.892508, -0.215035, -1.60025, 0.0719379, 1.55326, 2.05235] time: 132
# -6.2832 6.2832
# -2 0.75
# -3.1416 3.1416
# -3.2832 3.2832
# -3.2832 3.2832
# -6.2832 6.2832
# 1 1 1
# 2 1 1
# МЫ НАШЛИ РЕШЕНИЕ, МЫ НАШЛИ ЕГО
# NODES IN SOLUTION: 3
# ====================================================
# time: 25, [0.59292, -0.441263, -1.37433, 0.168734, 1.437, 1.08742]
# time: 35, [0.856538, -0.419604, -1.21647, -0.138263, 0.844537, 1.76555]
# time: 54.7002, [-0.892508, -0.215035, -1.60025, 0.0719379, 1.55326, 2.05235]
# [25, 35, 54.7002]
# 0x7ffc28d489b8 3 6 0
# [0.59292, -0.441263, -1.37433, 0.168734, 1.437, 1.08742,
#  0.856538, -0.419604, -1.21647, -0.138263, 0.844537, 1.76555,
#  -0.892508, -0.215035, -1.60025, 0.0719379, 1.55326, 2.05235]
# Путь робота записан в файл robot_path_20250611_034258_444.json
# t <= time(0)
# t: 25
# time(0): 25
# t >= time(time.d0-1)
# t: 55
# time(time.d0-1): 54.7002
# t <= time(0)
# t: 25
# time(0): 25
# t >= time(time.d0-1)
# t: 55
# time(time.d0-1): 55
# t <= time(0)
# t: 25
# time(0): 25
# t >= time(time.d0-1)
# t: 55
# time(time.d0-1): 55
# t0 55
# t_up 152
# РАЗМЕРНОСТЬ 6
# start:[-0.892508, -0.215035, -1.60025, 0.0719379, 1.55326, 2.05235] time: 55
# goal:[0, 0.5, -1.2, 0, 1.57, 1.57] time: 152
# -6.2832 6.2832
# -2 0.75
# -3.1416 3.1416
# -3.2832 3.2832
# -3.2832 3.2832
# -6.2832 6.2832
# 1 1 1
# 2 1 1
# МЫ НАШЛИ РЕШЕНИЕ, МЫ НАШЛИ ЕГО
# NODES IN SOLUTION: 3
# ====================================================
# time: 55, [-0.892508, -0.215035, -1.60025, 0.0719379, 1.55326, 2.05235]
# time: 65, [-0.479014, -0.258351, -1.01369, 0.38179, 1.85458, 1.50803]
# time: 75.3534, [0, 0.5, -1.2, 0, 1.57, 1.57]
# [55, 65, 75.3534]
# 0x7ffc28d489b8 3 6 0
# [-0.892508, -0.215035, -1.60025, 0.0719379, 1.55326, 2.05235,
#  -0.479014, -0.258351, -1.01369, 0.38179, 1.85458, 1.50803,
#  0, 0.5, -1.2, 0, 1.57, 1.57]
# Путь робота записан в файл robot_path_20250611_034258_729.json
# t <= time(0)
# t: 55
# time(0): 55
# t >= time(time.d0-1)
# t: 76
# time(time.d0-1): 75.3534
# t <= time(0)
# t: 55
# time(0): 55
# t >= time(time.d0-1)
# t: 76
# time(time.d0-1): 76
# t <= time(0)
# t: 55
# time(0): 55
# t >= time(time.d0-1)
# t: 76
# time(time.d0-1): 76
# t0 0
# t_up 130
# РАЗМЕРНОСТЬ 6
# start:[0, 0.5, -1.2, 0, 1.57, 1.57] time: 0
# goal:[0.79667, -0.341839, -1.47317, 0.195736, 1.40941, 1.18422] time: 130
# -6.2832 6.2832
# -2 0.75
# -3.1416 3.1416
# -3.2832 3.2832
# -3.2832 3.2832
# -6.2832 6.2832
# 1 1 1
# МЫ НАШЛИ РЕШЕНИЕ, МЫ НАШЛИ ЕГО
# NODES IN SOLUTION: 3
# ====================================================
# time: 0, [0, 0.5, -1.2, 0, 1.57, 1.57]
# time: 10, [-0.453632, 0.16877, -0.854528, -0.261021, 1.73294, 0.884089]
# time: 26.1657, [0.79667, -0.341839, -1.47317, 0.195736, 1.40941, 1.18422]
# [0, 10, 26.1657]
# 0x7ffc28d489b8 3 6 0
# [0, 0.5, -1.2, 0, 1.57, 1.57,
#  -0.453632, 0.16877, -0.854528, -0.261021, 1.73294, 0.884089,
#  0.79667, -0.341839, -1.47317, 0.195736, 1.40941, 1.18422]
# Путь робота записан в файл robot_path_20250611_034258_998.json
# t <= time(0)
# t: 0
# time(0): 0
# t >= time(time.d0-1)
# t: 27
# time(time.d0-1): 26.1657
# t <= time(0)
# t: 0
# time(0): 0
# t >= time(time.d0-1)
# t: 27
# time(time.d0-1): 27
# t <= time(0)
# t: 0
# time(0): 0
# t >= time(time.d0-1)
# t: 27
# time(time.d0-1): 27
# t0 27
# t_up 152
# РАЗМЕРНОСТЬ 6
# start:[0.79667, -0.341839, -1.47317, 0.195736, 1.40941, 1.18422] time: 27
# goal:[-1.82683, -0.319381, -1.52779, 0.116741, 1.473, 1.95578] time: 152
# -6.2832 6.2832
# -2 0.75
# -3.1416 3.1416
# -3.2832 3.2832
# -3.2832 3.2832
# -6.2832 6.2832
# 1 1 1
# 2 1 1
# 3 1 1
# 4 1 1
# 5 2 2
# 6 2 3
# 7 3 3
# 8 3 3
# 9 3 4
# 10 3 4
# 11 3 4
# 12 4 4
# 13 4 5
# 14 5 5
# 15 5 6
# 16 5 6
# 17 5 6
# 18 6 6
# 19 6 6
# 20 6 7
# 21 7 7
# 22 7 7
# 23 7 8
# 24 7 8
# МЫ НАШЛИ РЕШЕНИЕ, МЫ НАШЛИ ЕГО
# NODES IN SOLUTION: 3
# ====================================================
# time: 27, [0.79667, -0.341839, -1.47317, 0.195736, 1.40941, 1.18422]
# time: 67.8773, [0.110799, -0.322635, 0.17626, -0.954584, -1.23332, -0.717294]
# time: 115.113, [-1.82683, -0.319381, -1.52779, 0.116741, 1.473, 1.95578]
# [27, 67.8773, 115.113]
# 0x7ffc28d489b8 3 6 0
# [0.79667, -0.341839, -1.47317, 0.195736, 1.40941, 1.18422,
#  0.110799, -0.322635, 0.17626, -0.954584, -1.23332, -0.717294,
#  -1.82683, -0.319381, -1.52779, 0.116741, 1.473, 1.95578]
# Путь робота записан в файл robot_path_20250611_034259_571.json
# t <= time(0)
# t: 27
# time(0): 27
# t >= time(time.d0-1)
# t: 116
# time(time.d0-1): 115.113
# [2025-06-11 03:42:59.578] [error] resampled path is not feasible! This should not happen.
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 1
# [2025-06-11 03:42:59.579] [error] resampled path is not feasible! This should not happen.
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 1
# t <= time(0)
# t: 27
# time(0): 27
# t >= time(time.d0-1)
# t: 116
# time(time.d0-1): 116
# t <= time(0)
# t: 27
# time(0): 27
# t >= time(time.d0-1)
# t: 116
# time(time.d0-1): 116
# t0 116
# t_up 228
# РАЗМЕРНОСТЬ 6
# start:[-1.82683, -0.319381, -1.52779, 0.116741, 1.473, 1.95578] time: 116
# goal:[0, 0.5, -1.2, 0, 1.57, 1.57] time: 228
# -6.2832 6.2832
# -2 0.75
# -3.1416 3.1416
# -3.2832 3.2832
# -3.2832 3.2832
# -6.2832 6.2832
# 1 1 1
# МЫ НАШЛИ РЕШЕНИЕ, МЫ НАШЛИ ЕГО
# NODES IN SOLUTION: 3
# ====================================================
# time: 116, [-1.82683, -0.319381, -1.52779, 0.116741, 1.473, 1.95578]
# time: 126, [-1.17041, -0.201784, -1.4731, -0.306976, 0.912048, 2.19679]
# time: 142.912, [0, 0.5, -1.2, 0, 1.57, 1.57]
# [116, 126, 142.912]
# 0x7ffc28d489b8 3 6 0
# [-1.82683, -0.319381, -1.52779, 0.116741, 1.473, 1.95578,
#  -1.17041, -0.201784, -1.4731, -0.306976, 0.912048, 2.19679,
#  0, 0.5, -1.2, 0, 1.57, 1.57]
# Путь робота записан в файл robot_path_20250611_034300_141.json
# t <= time(0)
# t: 116
# time(0): 116
# t >= time(time.d0-1)
# t: 143
# time(time.d0-1): 142.912
# t <= time(0)
# t: 116
# time(0): 116
# t >= time(time.d0-1)
# t: 143
# time(time.d0-1): 143
# t <= time(0)
# t: 116
# time(0): 116
# t >= time(time.d0-1)
# t: 143
# time(time.d0-1): 143
# t0 47
# t_up 155
# РАЗМЕРНОСТЬ 6
# start:[0, 0.5, -1.2, 0, 1.57, 1.57] time: 47
# goal:[1.32445, -0.367777, -1.46572, 0.339732, 1.93103, 0.742325] time: 155
# -6.2832 6.2832
# -2 0.75
# -3.1416 3.1416
# -3.2832 3.2832
# -3.2832 3.2832
# -6.2832 6.2832
# 1 1 1
# МЫ НАШЛИ РЕШЕНИЕ, МЫ НАШЛИ ЕГО
# NODES IN SOLUTION: 3
# ====================================================
# time: 47, [0, 0.5, -1.2, 0, 1.57, 1.57]
# time: 57, [0.53171, 0.48161, -0.462508, 0.0759421, 1.84166, 1.26424]
# time: 74.4609, [1.32445, -0.367777, -1.46572, 0.339732, 1.93103, 0.742325]
# [47, 57, 74.4609]
# 0x7ffc28d489b8 3 6 0
# [0, 0.5, -1.2, 0, 1.57, 1.57,
#  0.53171, 0.48161, -0.462508, 0.0759421, 1.84166, 1.26424,
#  1.32445, -0.367777, -1.46572, 0.339732, 1.93103, 0.742325]
# Путь робота записан в файл robot_path_20250611_034300_405.json
# t <= time(0)
# t: 47
# time(0): 47
# t >= time(time.d0-1)
# t: 75
# time(time.d0-1): 74.4609
# t <= time(0)
# t: 47
# time(0): 47
# t >= time(time.d0-1)
# t: 75
# time(time.d0-1): 75
# t <= time(0)
# t: 47
# time(0): 47
# t >= time(time.d0-1)
# t: 75
# time(time.d0-1): 75
# t0 75
# t_up 216
# РАЗМЕРНОСТЬ 6
# start:[1.32445, -0.367777, -1.46572, 0.339732, 1.93103, 0.742325] time: 75
# goal:[-1.62342, -0.787407, -0.829889, 0.404652, 1.43275, 2.39794] time: 216
# -6.2832 6.2832
# -2 0.75
# -3.1416 3.1416
# -3.2832 3.2832
# -3.2832 3.2832
# -6.2832 6.2832
# 1 1 1
# МЫ НАШЛИ РЕШЕНИЕ, МЫ НАШЛИ ЕГО
# NODES IN SOLUTION: 3
# ====================================================
# time: 75, [1.32445, -0.367777, -1.46572, 0.339732, 1.93103, 0.742325]
# time: 85, [1.57587, -0.273331, -0.779325, 0.244709, 1.31609, 0.47861]
# time: 134.726, [-1.62342, -0.787407, -0.829889, 0.404652, 1.43275, 2.39794]
# [75, 85, 134.726]
# 0x7ffc28d489b8 3 6 0
# [1.32445, -0.367777, -1.46572, 0.339732, 1.93103, 0.742325,
#  1.57587, -0.273331, -0.779325, 0.244709, 1.31609, 0.47861,
#  -1.62342, -0.787407, -0.829889, 0.404652, 1.43275, 2.39794]
# Путь робота записан в файл robot_path_20250611_034300_944.json
# t <= time(0)
# t: 75
# time(0): 75
# t >= time(time.d0-1)
# t: 135
# time(time.d0-1): 134.726
# t <= time(0)
# t: 75
# time(0): 75
# t >= time(time.d0-1)
# t: 135
# time(time.d0-1): 135
# t <= time(0)
# t: 75
# time(0): 75
# t >= time(time.d0-1)
# t: 135
# time(time.d0-1): 135
# t0 135
# t_up 304
# РАЗМЕРНОСТЬ 6
# start:[4.65976, -0.787407, -0.829889, 0.404652, 1.43275, 2.39794] time: 135
# goal:[0, 0.5, -1.2, 0, 1.57, 1.57] time: 304
# -6.2832 6.2832
# -2 0.75
# -3.1416 3.1416
# -3.2832 3.2832
# -3.2832 3.2832
# -6.2832 6.2832
# 1 1 1
# МЫ НАШЛИ РЕШЕНИЕ, МЫ НАШЛИ ЕГО
# NODES IN SOLUTION: 3
# ====================================================
# time: 135, [4.65976, -0.787407, -0.829889, 0.404652, 1.43275, 2.39794]
# time: 145, [4.82208, -0.919199, -1.14211, 0.299008, 0.541359, 2.62828]
# time: 197.486, [0, 0.5, -1.2, 0, 1.57, 1.57]
# [135, 145, 197.486]
# 0x7ffc28d489b8 3 6 0
# [4.65976, -0.787407, -0.829889, 0.404652, 1.43275, 2.39794,
#  4.82208, -0.919199, -1.14211, 0.299008, 0.541359, 2.62828,
#  0, 0.5, -1.2, 0, 1.57, 1.57]
# Путь робота записан в файл robot_path_20250611_034301_573.json
# t <= time(0)
# t: 135
# time(0): 135
# t >= time(time.d0-1)
# t: 198
# time(time.d0-1): 197.486
# t <= time(0)
# t: 135
# time(0): 135
# t >= time(time.d0-1)
# t: 198
# time(time.d0-1): 198
# t <= time(0)
# t: 135
# time(0): 135
# t >= time(time.d0-1)
# t: 198
# time(time.d0-1): 198
# t0 66
# t_up 210
# РАЗМЕРНОСТЬ 6
# start:[0, 0.5, -1.2, 0, 1.57, 1.57] time: 66
# goal:[1.35097, -0.900983, -0.752707, 0.750967, 1.48325, -0.306582] time: 210
# -6.2832 6.2832
# -2 0.75
# -3.1416 3.1416
# -3.2832 3.2832
# -3.2832 3.2832
# -6.2832 6.2832
# 1 1 1
# МЫ НАШЛИ РЕШЕНИЕ, МЫ НАШЛИ ЕГО
# NODES IN SOLUTION: 3
# ====================================================
# time: 66, [0, 0.5, -1.2, 0, 1.57, 1.57]
# time: 76, [0.367136, 0.401206, -1.11481, -0.0476391, 1.67087, 0.655807]
# time: 96.9716, [1.35097, -0.900983, -0.752707, 0.750967, 1.48325, -0.306582]
# [66, 76, 96.9716]
# 0x7ffc28d489b8 3 6 0
# [0, 0.5, -1.2, 0, 1.57, 1.57,
#  0.367136, 0.401206, -1.11481, -0.0476391, 1.67087, 0.655807,
#  1.35097, -0.900983, -0.752707, 0.750967, 1.48325, -0.306582]
# Путь робота записан в файл robot_path_20250611_034301_988.json
# t <= time(0)
# t: 66
# time(0): 66
# t >= time(time.d0-1)
# t: 97
# time(time.d0-1): 96.9716
# t <= time(0)
# t: 66
# time(0): 66
# t >= time(time.d0-1)
# t: 97
# time(time.d0-1): 97
# t <= time(0)
# t: 66
# time(0): 66
# t >= time(time.d0-1)
# t: 97
# time(time.d0-1): 97
# t0 97
# t_up 249
# РАЗМЕРНОСТЬ 6
# start:[1.35097, -0.900983, -0.752707, 0.750967, 1.48325, -0.306582] time: 97
# goal:[1.53868, -0.198357, -1.62462, -0.228856, 2.0821, 3.44665] time: 249
# [2025-06-11 03:43:02.290] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034302_290.json
# t0 97
# t_up 269
# РАЗМЕРНОСТЬ 6
# start:[1.35097, -0.900983, -0.752707, 0.750967, 1.48325, -0.306582] time: 97
# goal:[1.53868, -0.198357, -1.62462, -0.228856, 2.0821, 3.44665] time: 269
# [2025-06-11 03:43:02.502] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034302_502.json
# t0 97
# t_up 289
# РАЗМЕРНОСТЬ 6
# start:[1.35097, -0.900983, -0.752707, 0.750967, 1.48325, -0.306582] time: 97
# goal:[1.53868, -0.198357, -1.62462, -0.228856, 2.0821, 3.44665] time: 289
# [2025-06-11 03:43:02.688] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034302_688.json
# t0 97
# t_up 309
# РАЗМЕРНОСТЬ 6
# start:[1.35097, -0.900983, -0.752707, 0.750967, 1.48325, -0.306582] time: 97
# goal:[1.53868, -0.198357, -1.62462, -0.228856, 2.0821, 3.44665] time: 309
# [2025-06-11 03:43:02.902] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034302_902.json
# t0 97
# t_up 329
# РАЗМЕРНОСТЬ 6
# start:[1.35097, -0.900983, -0.752707, 0.750967, 1.48325, -0.306582] time: 97
# goal:[1.53868, -0.198357, -1.62462, -0.228856, 2.0821, 3.44665] time: 329
# [2025-06-11 03:43:03.168] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034303_168.json
# t0 97
# t_up 349
# РАЗМЕРНОСТЬ 6
# start:[1.35097, -0.900983, -0.752707, 0.750967, 1.48325, -0.306582] time: 97
# goal:[1.53868, -0.198357, -1.62462, -0.228856, 2.0821, 3.44665] time: 349
# [2025-06-11 03:43:03.522] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034303_522.json
# t0 97
# t_up 369
# РАЗМЕРНОСТЬ 6
# start:[1.35097, -0.900983, -0.752707, 0.750967, 1.48325, -0.306582] time: 97
# goal:[1.53868, -0.198357, -1.62462, -0.228856, 2.0821, 3.44665] time: 369
# [2025-06-11 03:43:03.862] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034303_862.json
# t0 97
# t_up 389
# РАЗМЕРНОСТЬ 6
# start:[1.35097, -0.900983, -0.752707, 0.750967, 1.48325, -0.306582] time: 97
# goal:[1.53868, -0.198357, -1.62462, -0.228856, 2.0821, 3.44665] time: 389
# [2025-06-11 03:43:04.251] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034304_251.json
# t0 97
# t_up 409
# РАЗМЕРНОСТЬ 6
# start:[1.35097, -0.900983, -0.752707, 0.750967, 1.48325, -0.306582] time: 97
# goal:[1.53868, -0.198357, -1.62462, -0.228856, 2.0821, 3.44665] time: 409
# [2025-06-11 03:43:04.563] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034304_564.json
# t0 97
# t_up 429
# РАЗМЕРНОСТЬ 6
# start:[1.35097, -0.900983, -0.752707, 0.750967, 1.48325, -0.306582] time: 97
# goal:[1.53868, -0.198357, -1.62462, -0.228856, 2.0821, 3.44665] time: 429
# [2025-06-11 03:43:04.860] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034304_860.json
# Объединённый файл сохранён: /home/alex/multitask/24-data-gen/result.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034300_944.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034259_571.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034258_250.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034303_862.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034258_444.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034303_168.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034302_290.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034300_141.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034258_998.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034302_902.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034304_251.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034302_502.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034301_573.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034301_988.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034304_860.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034300_405.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034258_729.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034302_688.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034303_522.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034304_564.json
# ** INFO:util.cpp:initCmdLine:596(1) ** cmd line arguments: './sipp.exe -pnp true -mode random_search -seed 879 -robot_path in/random/2717/robot_path.json -obj_path in/random/2717/obj_path.json -attempt_komo false -display false -export_images false -scene_path in/random/2717/scene.g -obstacle_path in/random/2717/obstacles_file.json'
# ** INFO:util.cpp:initCmdLine:600(1) ** run path: '/home/alex/multitask/24-data-gen'
# ** INFO:graph.cpp:initParameters:1359(1) ** parsed parameters:
# {pnp,
# mode:"random_search",
# seed:879,
# robot_path:"in/random/2717/robot_path.json",
# obj_path:"in/random/2717/obj_path.json",
# attempt_komo!,
# display!,
# export_images!,
# scene_path:"in/random/2717/scene.g",
# obstacle_path:"in/random/2717/obstacles_file.json",
# display!,
# export_images!,
# early_stopping,
# objects:5,
# vmax:0.1,
# smoothing,
# attempt_komo!}
#
# ** WARNING:util.cpp:getIs:1081(-1) could not open file 'scene.g' for input from '/home/alex/multitask/24-data-gen./in/random/2717'
# Объединённый файл сохранён: /home/alex/multitask/24-data-gen/result.json
# ** INFO:util.cpp:initCmdLine:596(1) ** cmd line arguments: './sipp.exe -pnp true -mode random_search -seed 1 -robot_path in/random/2717/robot_path.json -obj_path in/random/2717/obj_path.json -attempt_komo false -display false -export_images false'
# ** INFO:util.cpp:initCmdLine:600(1) ** run path: '/home/alex/multitask/24-data-gen'
# ** INFO:graph.cpp:initParameters:1359(1) ** parsed parameters:
# {pnp,
# mode:"random_search",
# seed:1,
# robot_path:"in/random/2717/robot_path.json",
# obj_path:"in/random/2717/obj_path.json",
# attempt_komo!,
# display!,
# export_images!,
# display!,
# export_images!,
# early_stopping,
# objects:5,
# vmax:0.1,
# smoothing,
# attempt_komo!}
#
# ** WARNING:switch.cpp:conv_times2tuples:38(-1) beyond the time!: endTime=5 phases=2
# ** WARNING:switch.cpp:conv_times2tuples:38(-1) beyond the time!: endTime=5 phases=2
# t0 0
# t_up 108
# РАЗМЕРНОСТЬ 6
# start:[0, 0.5, -1.2, 0, 1.57, 1.57] time: 0
# goal:[1.32408, -0.367571, -1.46659, 0.341532, 1.93248, 0.741321] time: 108
# -6.2832 6.2832
# -2 0.75
# -3.1416 3.1416
# -3.2832 3.2832
# -3.2832 3.2832
# -6.2832 6.2832
# 1 1 1
# МЫ НАШЛИ РЕШЕНИЕ, МЫ НАШЛИ ЕГО
# NODES IN SOLUTION: 3
# ====================================================
# time: 0, [0, 0.5, -1.2, 0, 1.57, 1.57]
# time: 10, [0.46878, 0.134352, -1.25596, -0.231839, 1.23094, 2.25899]
# time: 30.3866, [1.32408, -0.367571, -1.46659, 0.341532, 1.93248, 0.741321]
# [0, 10, 30.3866]
# 0x7fff603fab38 3 6 0
# [0, 0.5, -1.2, 0, 1.57, 1.57,
#  0.46878, 0.134352, -1.25596, -0.231839, 1.23094, 2.25899,
#  1.32408, -0.367571, -1.46659, 0.341532, 1.93248, 0.741321]
# Путь робота записан в файл robot_path_20250611_034308_927.json
# t <= time(0)
# t: 0
# time(0): 0
# t >= time(time.d0-1)
# t: 31
# time(time.d0-1): 30.3866
# t <= time(0)
# t: 0
# time(0): 0
# t >= time(time.d0-1)
# t: 31
# time(time.d0-1): 31
# t <= time(0)
# t: 0
# time(0): 0
# t >= time(time.d0-1)
# t: 31
# time(time.d0-1): 31
# t0 31
# t_up 172
# РАЗМЕРНОСТЬ 6
# start:[1.32408, -0.367571, -1.46659, 0.341532, 1.93248, 0.741321] time: 31
# goal:[-1.62422, -0.788018, -0.828523, 0.403461, 1.43544, 2.39915] time: 172
# -6.2832 6.2832
# -2 0.75
# -3.1416 3.1416
# -3.2832 3.2832
# -3.2832 3.2832
# -6.2832 6.2832
# 1 1 1
# 2 1 1
# МЫ НАШЛИ РЕШЕНИЕ, МЫ НАШЛИ ЕГО
# NODES IN SOLUTION: 3
# ====================================================
# time: 31, [1.32408, -0.367571, -1.46659, 0.341532, 1.93248, 0.741321]
# time: 41, [1.53871, -0.359479, -1.30407, 0.0265584, 1.29797, 1.39373]
# time: 75.0479, [-1.62422, -0.788018, -0.828523, 0.403461, 1.43544, 2.39915]
# [31, 41, 75.0479]
# 0x7fff603fab38 3 6 0
# [1.32408, -0.367571, -1.46659, 0.341532, 1.93248, 0.741321,
#  1.53871, -0.359479, -1.30407, 0.0265584, 1.29797, 1.39373,
#  -1.62422, -0.788018, -0.828523, 0.403461, 1.43544, 2.39915]
# Путь робота записан в файл robot_path_20250611_034309_417.json
# t <= time(0)
# t: 31
# time(0): 31
# t >= time(time.d0-1)
# t: 76
# time(time.d0-1): 75.0479
# t <= time(0)
# t: 31
# time(0): 31
# t >= time(time.d0-1)
# t: 76
# time(time.d0-1): 76
# t <= time(0)
# t: 31
# time(0): 31
# t >= time(time.d0-1)
# t: 76
# time(time.d0-1): 76
# t0 76
# t_up 245
# РАЗМЕРНОСТЬ 6
# start:[4.65896, -0.788018, -0.828523, 0.403461, 1.43544, 2.39915] time: 76
# goal:[0, 0.5, -1.2, 0, 1.57, 1.57] time: 245
# -6.2832 6.2832
# -2 0.75
# -3.1416 3.1416
# -3.2832 3.2832
# -3.2832 3.2832
# -6.2832 6.2832
# 1 1 1
# МЫ НАШЛИ РЕШЕНИЕ, МЫ НАШЛИ ЕГО
# NODES IN SOLUTION: 3
# ====================================================
# time: 76, [4.65896, -0.788018, -0.828523, 0.403461, 1.43544, 2.39915]
# time: 86, [3.94787, -0.859576, -1.03253, 0.530727, 1.06699, 1.8554]
# time: 128.529, [0, 0.5, -1.2, 0, 1.57, 1.57]
# [76, 86, 128.529]
# 0x7fff603fab38 3 6 0
# [4.65896, -0.788018, -0.828523, 0.403461, 1.43544, 2.39915,
#  3.94787, -0.859576, -1.03253, 0.530727, 1.06699, 1.8554,
#  0, 0.5, -1.2, 0, 1.57, 1.57]
# Путь робота записан в файл robot_path_20250611_034310_245.json
# t <= time(0)
# t: 76
# time(0): 76
# t >= time(time.d0-1)
# t: 129
# time(time.d0-1): 128.529
# t <= time(0)
# t: 76
# time(0): 76
# t >= time(time.d0-1)
# t: 129
# time(time.d0-1): 129
# t <= time(0)
# t: 76
# time(0): 76
# t >= time(time.d0-1)
# t: 129
# time(time.d0-1): 129
# t0 7
# t_up 151
# РАЗМЕРНОСТЬ 6
# start:[0, 0.5, -1.2, 0, 1.57, 1.57] time: 7
# goal:[1.35193, -0.901961, -0.751923, 0.74901, 1.47984, -0.307976] time: 151
# -6.2832 6.2832
# -2 0.75
# -3.1416 3.1416
# -3.2832 3.2832
# -3.2832 3.2832
# -6.2832 6.2832
# 1 1 1
# МЫ НАШЛИ РЕШЕНИЕ, МЫ НАШЛИ ЕГО
# NODES IN SOLUTION: 3
# ====================================================
# time: 7, [0, 0.5, -1.2, 0, 1.57, 1.57]
# time: 17, [0.350329, 0.358554, -0.781831, 0.262976, 1.81287, 0.825516]
# time: 37.5647, [1.35193, -0.901961, -0.751923, 0.74901, 1.47984, -0.307976]
# [7, 17, 37.5647]
# 0x7fff603fab38 3 6 0
# [0, 0.5, -1.2, 0, 1.57, 1.57,
#  0.350329, 0.358554, -0.781831, 0.262976, 1.81287, 0.825516,
#  1.35193, -0.901961, -0.751923, 0.74901, 1.47984, -0.307976]
# Путь робота записан в файл robot_path_20250611_034311_269.json
# t <= time(0)
# t: 7
# time(0): 7
# t >= time(time.d0-1)
# t: 38
# time(time.d0-1): 37.5647
# t <= time(0)
# t: 7
# time(0): 7
# t >= time(time.d0-1)
# t: 38
# time(time.d0-1): 38
# t <= time(0)
# t: 7
# time(0): 7
# t >= time(time.d0-1)
# t: 38
# time(time.d0-1): 38
# t0 38
# t_up 190
# РАЗМЕРНОСТЬ 6
# start:[1.35193, -0.901961, -0.751923, 0.74901, 1.47984, -0.307976] time: 38
# goal:[1.53978, -0.196918, -1.62584, -0.225533, 2.07879, 3.44803] time: 190
# [2025-06-11 03:43:11.702] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034311_702.json
# t0 38
# t_up 210
# РАЗМЕРНОСТЬ 6
# start:[1.35193, -0.901961, -0.751923, 0.74901, 1.47984, -0.307976] time: 38
# goal:[1.53978, -0.196918, -1.62584, -0.225533, 2.07879, 3.44803] time: 210
# [2025-06-11 03:43:11.995] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034311_995.json
# t0 38
# t_up 230
# РАЗМЕРНОСТЬ 6
# start:[1.35193, -0.901961, -0.751923, 0.74901, 1.47984, -0.307976] time: 38
# goal:[1.53978, -0.196918, -1.62584, -0.225533, 2.07879, 3.44803] time: 230
# [2025-06-11 03:43:12.395] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034312_395.json
# t0 38
# t_up 250
# РАЗМЕРНОСТЬ 6
# start:[1.35193, -0.901961, -0.751923, 0.74901, 1.47984, -0.307976] time: 38
# goal:[1.53978, -0.196918, -1.62584, -0.225533, 2.07879, 3.44803] time: 250
# [2025-06-11 03:43:12.893] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034312_893.json
# t0 38
# t_up 270
# РАЗМЕРНОСТЬ 6
# start:[1.35193, -0.901961, -0.751923, 0.74901, 1.47984, -0.307976] time: 38
# goal:[1.53978, -0.196918, -1.62584, -0.225533, 2.07879, 3.44803] time: 270
# [2025-06-11 03:43:13.431] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034313_431.json
# t0 38
# t_up 290
# РАЗМЕРНОСТЬ 6
# start:[1.35193, -0.901961, -0.751923, 0.74901, 1.47984, -0.307976] time: 38
# goal:[1.53978, -0.196918, -1.62584, -0.225533, 2.07879, 3.44803] time: 290
# [2025-06-11 03:43:14.085] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034314_085.json
# t0 38
# t_up 310
# РАЗМЕРНОСТЬ 6
# start:[1.35193, -0.901961, -0.751923, 0.74901, 1.47984, -0.307976] time: 38
# goal:[1.53978, -0.196918, -1.62584, -0.225533, 2.07879, 3.44803] time: 310
# [2025-06-11 03:43:14.798] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034314_798.json
# t0 38
# t_up 330
# РАЗМЕРНОСТЬ 6
# start:[1.35193, -0.901961, -0.751923, 0.74901, 1.47984, -0.307976] time: 38
# goal:[1.53978, -0.196918, -1.62584, -0.225533, 2.07879, 3.44803] time: 330
# [2025-06-11 03:43:15.426] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034315_426.json
# t0 38
# t_up 350
# РАЗМЕРНОСТЬ 6
# start:[1.35193, -0.901961, -0.751923, 0.74901, 1.47984, -0.307976] time: 38
# goal:[1.53978, -0.196918, -1.62584, -0.225533, 2.07879, 3.44803] time: 350
# [2025-06-11 03:43:15.818] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034315_818.json
# t0 38
# t_up 370
# РАЗМЕРНОСТЬ 6
# start:[1.35193, -0.901961, -0.751923, 0.74901, 1.47984, -0.307976] time: 38
# goal:[1.53978, -0.196918, -1.62584, -0.225533, 2.07879, 3.44803] time: 370
# [2025-06-11 03:43:16.300] [error] safe_intervals is empty in the goal point
# Путь робота записан в файл robot_path_20250611_034316_300.json
# Объединённый файл сохранён: /home/alex/multitask/24-data-gen/result.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034315_426.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034314_085.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034311_702.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034308_927.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034315_818.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034311_995.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034316_300.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034312_893.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034311_269.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034314_798.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034309_417.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034312_395.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034310_245.json
# Deleted: /home/alex/multitask/24-data-gen/log/robot_path_20250611_034313_431.json
# ** INFO:util.cpp:initCmdLine:596(1) ** cmd line arguments: './sipp.exe -pnp true -mode random_search -seed 1 -robot_path in/random/2717/robot_path.json -obj_path in/random/2717/obj_path.json -attempt_komo false -display false -export_images false -scene_path in/random/2717/scene.g -obstacle_path in/random/2717/obstacles_file.json'
# ** INFO:util.cpp:initCmdLine:600(1) ** run path: '/home/alex/multitask/24-data-gen'
# ** INFO:graph.cpp:initParameters:1359(1) ** parsed parameters:
# {pnp,
# mode:"random_search",
# seed:1,
# robot_path:"in/random/2717/robot_path.json",
# obj_path:"in/random/2717/obj_path.json",
# attempt_komo!,
# display!,
# export_images!,
# scene_path:"in/random/2717/scene.g",
# obstacle_path:"in/random/2717/obstacles_file.json",
# display!,
# export_images!,
# early_stopping,
# objects:5,
# vmax:0.1,
# smoothing,
# attempt_komo!}
#
# ** WARNING:util.cpp:getIs:1081(-1) could not open file 'scene.g' for input from '/home/alex/multitask/24-data-gen./in/random/2717'
# Объединённый файл сохранён: /home/alex/multitask/24-data-gen/result.json
# ** INFO:util.cpp:initCmdLine:596(1) ** cmd line arguments: './sipp.exe -pnp true -mode random_search -seed 325 -robot_path in/random/2717/robot_path.json -obj_path in/random/2717/obj_path.json -attempt_komo false -display false -export_images false'
# ** INFO:util.cpp:initCmdLine:600(1) ** run path: '/home/alex/multitask/24-data-gen'
# ** INFO:graph.cpp:initParameters:1359(1) ** parsed parameters:
# {pnp,
# mode:"random_search",
# seed:325,
# robot_path:"in/random/2717/robot_path.json",
# obj_path:"in/random/2717/obj_path.json",
# attempt_komo!,
# display!,
# export_images!,
# display!,
# export_images!,
# early_stopping,
# objects:5,
# vmax:0.1,
# smoothing,
# attempt_komo!}
#   0%|          | 0/260 [00:24<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 32
#      29 # validate_data(args)
#      31 clear_dir(directory)
# ---> 32 subprocess.run(command)
#      33 merge_robot_results("/home/alex/multitask/24-data-gen/log", "/home/alex/multitask/24-data-gen/result.json")
#      34 sort_data("/home/alex/multitask/24-data-gen/result.json", f"/home/alex/multitask/24-data-gen/stats_random/sipp_{folder}.json")
#
# File /usr/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File /usr/lib/python3.10/subprocess.py:1146, in Popen.communicate(self, input, timeout)
#    1144         stderr = self.stderr.read()
#    1145         self.stderr.close()
# -> 1146     self.wait()
#    1147 else:
#    1148     if timeout is not None:
#
# File /usr/lib/python3.10/subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File /usr/lib/python3.10/subprocess.py:1959, in Popen._wait(self, timeout)
#    1957 if self.returncode is not None:
#    1958     break  # Another thread waited.
# -> 1959 (pid, sts) = self._try_wait(0)
#    1960 # Check the pid and loop as waitpid has been known to
#    1961 # return 0 even without WNOHANG in odd situations.
#    1962 # http://bugs.python.org/issue14396.
#    1963 if pid == self.pid:
#
# File /usr/lib/python3.10/subprocess.py:1917, in Popen._try_wait(self, wait_flags)
#    1915 """All callers to this function MUST hold self._waitpid_lock."""
#    1916 try:
# -> 1917     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1918 except ChildProcessError:
#    1919     # This happens if SIGCLD is set to be ignored or waiting
#    1920     # for child processes has otherwise been disabled for our
#    1921     # process.  This child is dead, we can't get the status.
#    1922     pid = self.pid
#
# KeyboardInterrupt:

# %%
import os

sipp_files = [f for f in os.listdir("/home/alex/multitask/24-data-gen/stats_random") if f.startswith("sipp_") and f.endswith(".json")]
rrt_files = [f for f in os.listdir("/home/alex/multitask/24-data-gen/stats_random") if f.startswith("rrt_") and f.endswith(".json")]

print("SIPP-файлы:", sipp_files)
print("RRT-файлы:", rrt_files)
# Out:
# SIPP-файлы: ['sipp_9541.json', 'sipp_1488.json', 'sipp_5626.json', 'sipp_433.json', 'sipp_8604.json', 'sipp_7758.json', 'sipp_5064.json', 'sipp_943.json', 'sipp_5757.json', 'sipp_8612.json', 'sipp_8220.json', 'sipp_3219.json', 'sipp_1285.json', 'sipp_8371.json', 'sipp_123.json', 'sipp_3921.json', 'sipp_3500.json', 'sipp_6303.json', 'sipp_6848.json', 'sipp_9901.json', 'sipp_280.json', 'sipp_5602.json', 'sipp_6927.json', 'sipp_7962.json', 'sipp_9756.json', 'sipp_6766.json', 'sipp_2914.json', 'sipp_7508.json', 'sipp_8438.json', 'sipp_3228.json', 'sipp_4153.json', 'sipp_4441.json', 'sipp_1764.json', 'sipp_366.json', 'sipp_8731.json', 'sipp_5917.json', 'sipp_8100.json', 'sipp_566.json', 'sipp_4729.json', 'sipp_135.json', 'sipp_2717.json', 'sipp_1686.json', 'sipp_4592.json', 'sipp_7101.json', 'sipp_1182.json', 'sipp_7778.json', 'sipp_2511.json', 'sipp_1583.json', 'sipp_7285.json', 'sipp_924.json']
# RRT-файлы: ['rrt_7285.json', 'rrt_7778.json', 'rrt_4592.json', 'rrt_5626.json', 'rrt_5602.json', 'rrt_943.json', 'rrt_7101.json', 'rrt_4729.json', 'rrt_433.json', 'rrt_8371.json', 'rrt_1764.json', 'rrt_2717.json', 'rrt_3921.json', 'rrt_1285.json', 'rrt_4441.json', 'rrt_566.json', 'rrt_924.json', 'rrt_7508.json', 'rrt_8612.json', 'rrt_8220.json', 'rrt_4153.json', 'rrt_9541.json', 'rrt_7962.json', 'rrt_1488.json', 'rrt_1583.json', 'rrt_5757.json', 'rrt_3219.json', 'rrt_9901.json', 'rrt_9756.json', 'rrt_3500.json', 'rrt_1686.json', 'rrt_7758.json', 'rrt_6766.json', 'rrt_5064.json', 'rrt_5917.json', 'rrt_6927.json', 'rrt_8604.json', 'rrt_2511.json', 'rrt_8100.json', 'rrt_280.json', 'rrt_8731.json', 'rrt_1182.json', 'rrt_366.json', 'rrt_8438.json', 'rrt_3228.json', 'rrt_123.json', 'rrt_6303.json', 'rrt_2914.json', 'rrt_6848.json']

# %%
import json
import math

def calculate_trajectory_length(path):
    total_length = 0.0
    for i in range(1, len(path)):
        q1 = path[i - 1]["q"]
        q2 = path[i]["q"]
        diff = sum((a - b) ** 2 for a, b in zip(q1, q2))
        total_length += math.sqrt(diff)
    return total_length

def process_file(filename):
    with open(filename, "r", encoding="utf-8") as f:
        data = json.load(f)

    results = {}

    for robot_name, paths in data.items():
        total_planning_time = 0
        total_trajectory_length = 0.0
        total_movement_time = 0.0

        for path_info in paths:
            # Суммируем planning_time
            total_planning_time += path_info["planning_time"]

            # Вычисляем длину траектории
            path = path_info["path"]
            trajectory_length = calculate_trajectory_length(path)
            total_trajectory_length += trajectory_length

            # Время движения по траектории
            if len(path) >= 2:
                movement_time = path[-1]["t"] - path[0]["t"]
                total_movement_time += movement_time

        results[robot_name] = {
            "total_planning_time": total_planning_time,
            "total_trajectory_length": round(total_trajectory_length, 4),
            "total_movement_time": round(total_movement_time, 2)
        }

    return results

# Обработка файла

# %%
s_total_planning_time = []
s_total_trajectory_length = []
s_total_movement_time = []

for file in sipp_files:
    results = process_file("/home/alex/multitask/24-data-gen/stats_random/" + file)
    s_total_planning_time.append(sum([results[robot]['total_planning_time'] for robot in results.keys()]))
    s_total_trajectory_length.append(sum([results[robot]['total_trajectory_length'] for robot in results.keys()]))
    s_total_movement_time.append(sum([results[robot]['total_movement_time'] for robot in results.keys()]))

# %%
r_total_planning_time = []
r_total_trajectory_length = []
r_total_movement_time = []

for file in rrt_files:
    results = process_file("/home/alex/multitask/24-data-gen/stats_random/" + file)
    r_total_planning_time.append(sum([results[robot]['total_planning_time'] for robot in results.keys()]))
    r_total_trajectory_length.append(sum([results[robot]['total_trajectory_length'] for robot in results.keys()]))
    r_total_movement_time.append(sum([results[robot]['total_movement_time'] for robot in results.keys()]))

# %%
plt.rcParams.update({
    'font.size': 16,
    'axes.titlesize': 20,
    'axes.labelsize': 18,
    'xtick.labelsize': 16,
    'ytick.labelsize': 16,
    'legend.fontsize': 14,
    'lines.linewidth': 2,
    'boxplot.boxprops.linewidth': 2,
    'boxplot.whiskerprops.linewidth': 2,
    'boxplot.capprops.linewidth': 2,
    'boxplot.medianprops.linewidth': 2,
    'boxplot.flierprops.markersize': 6,
})

# %%
r_total_planning_time = [i for i in r_total_planning_time if i > 0.1]
r_total_trajectory_length = [i for i in r_total_trajectory_length if i > 0.1]
r_total_movement_time = [i for i in r_total_movement_time if i > 0.1]


s_total_planning_time = [i for i in s_total_planning_time if i > 0.1]
s_total_trajectory_length = [i for i in s_total_trajectory_length if i > 0.1]
s_total_movement_time = [i for i in s_total_movement_time if i > 0.1]

# %%
data_planning = [s_total_planning_time, r_total_planning_time]
data_trajectory = [s_total_trajectory_length, r_total_trajectory_length]
data_movement = [s_total_movement_time, r_total_movement_time]

labels = ['S', 'R']

# Создаем три графика
fig, axes = plt.subplots(1, 3, figsize=(15, 6))

# График 1: Время планирования
axes[0].boxplot(data_planning, labels=labels, showmeans=True)
axes[0].set_title('Planning Time')
axes[0].grid()
plt.grid()
# График 2: Длина траектории
axes[1].boxplot(data_trajectory, labels=labels, showmeans=True)
axes[1].set_title('Trajectory Length')
axes[1].grid()
# График 3: Время движения
axes[2].boxplot(data_movement, labels=labels, showmeans=True)
axes[2].set_title('Movement Time')
axes[2].grid()
# Оформление
plt.tight_layout()
# Out:
# /tmp/ipykernel_490/954468452.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[0].boxplot(data_planning, labels=labels, showmeans=True)
# /tmp/ipykernel_490/954468452.py:16: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot(data_trajectory, labels=labels, showmeans=True)
# /tmp/ipykernel_490/954468452.py:20: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[2].boxplot(data_movement, labels=labels, showmeans=True)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# Настраиваем стили через rcParams
plt.rcParams.update({
    'font.size': 16,
    'axes.titlesize': 20,
    'axes.labelsize': 18,
    'xtick.labelsize': 16,
    'ytick.labelsize': 16,
    'legend.fontsize': 14,
    'lines.linewidth': 2,
    'boxplot.boxprops.linewidth': 2,
    'boxplot.whiskerprops.linewidth': 2,
    'boxplot.capprops.linewidth': 2,
    'boxplot.medianprops.linewidth': 2,
    'boxplot.flierprops.markersize': 6,
})

# Данные
data_planning = [s_total_planning_time, r_total_planning_time]
data_trajectory = [s_total_trajectory_length, r_total_trajectory_length]
data_movement = [s_total_movement_time, r_total_movement_time]

labels = ['SIPP', 'RRT']

# Цвета для boxplots
colors = ['#66B2FF', "#D97D0C"]

# Создаем три графика
fig, axes = plt.subplots(1, 3, figsize=(16, 8))

# Функция для добавления цвета к boxplot
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color='black')
    plt.setp(bp['whiskers'], color='black')
    plt.setp(bp['caps'], color='black')
    plt.setp(bp['medians'], color='darkred')
    plt.setp(bp['fliers'], markeredgecolor='black')

    for patch, color in zip(bp['boxes'], color):
        patch.set_facecolor(color)

# График 1: Время планирования
bp1 = axes[0].boxplot(data_planning, positions=np.arange(len(data_planning)), widths=0.6, patch_artist=True)
set_box_color(bp1, colors)
axes[0].set_xticks(np.arange(len(labels)))
axes[0].set_xticklabels(labels)
axes[0].set_title('Planning Time')
axes[0].grid(True, linestyle='--', alpha=0.5)
axes[0].set_ylabel('milliseconds')

# График 2: Длина траектории
bp2 = axes[1].boxplot(data_trajectory, positions=np.arange(len(data_trajectory)), widths=0.6, patch_artist=True)
set_box_color(bp2, colors)
axes[1].set_xticks(np.arange(len(labels)))
axes[1].set_xticklabels(labels)
axes[1].set_title('Trajectory Length')
axes[1].grid(True, linestyle='--', alpha=0.5)
axes[1].set_ylabel('radians')

# График 3: Время движения
bp3 = axes[2].boxplot(data_movement, positions=np.arange(len(data_movement)), widths=0.6, patch_artist=True)
set_box_color(bp3, colors)
axes[2].set_xticks(np.arange(len(labels)))
axes[2].set_xticklabels(labels)
axes[2].set_title('Movement Time')
axes[2].grid(True, linestyle='--', alpha=0.5)
axes[2].set_ylabel('frames')

# Легенда
handles = [mpatches.Patch(color=colors[i], label=label) for i, label in enumerate(labels)]
fig.legend(handles=handles, loc="upper right", bbox_to_anchor=(0.9, 0.85))

# Оформление
plt.tight_layout()
plt.subplots_adjust(right=0.85)
plt.show()

# %%
results = process_file("/home/alex/multitask/24-data-gen/stats_random/" + sipp_files[10])
results
# Out:
# {'a2_': {'total_planning_time': 885,
#   'total_trajectory_length': 17.6374,
#   'total_movement_time': 233.9},
#  'a1_': {'total_planning_time': 539,
#   'total_trajectory_length': 8.1643,
#   'total_movement_time': 146.45},
#  'a0_': {'total_planning_time': 1138,
#   'total_trajectory_length': 14.0464,
#   'total_movement_time': 140.52}}

# %%
results = process_file("/home/alex/multitask/24-data-gen/stats_random/" + sipp_files[10])
results
# Out:
# {'a2_': {'total_planning_time': 885,
#   'total_trajectory_length': 17.6374,
#   'total_movement_time': 233.9},
#  'a1_': {'total_planning_time': 539,
#   'total_trajectory_length': 8.1643,
#   'total_movement_time': 146.45},
#  'a0_': {'total_planning_time': 1138,
#   'total_trajectory_length': 14.0464,
#   'total_movement_time': 140.52}}

# %%
a = input()
        travel_time = 0.0
        path_length = 0.0
        total_rrt_time = 0.0
        total_coll_time = 0.0
        total_nn_time = 0.0
        
        for filename in os.listdir('/home/alex/multitask/24-data-gen/log'):
            if filename.endswith('.json'):
                try:
                    with open('/home/alex/multitask/24-data-gen/log/' + filename, 'r') as f:
                        data = json.load(f)

                        if data['travel_time'] != 0:
                            travel_time     += data['travel_time']
                            path_length     += data['path_length']
                            total_rrt_time  += data['total_rrt_time']
                            total_coll_time += data['total_coll_time']
                            total_nn_time   += data['total_nn_time']

                        print(f"Содержимое файла {filename}:")
                        print(json.dumps(data, indent=4))
                    
                except Exception as e:
                    print(f"Ошибка при обработке файла {filename}: {e}\n")
shelf_stats[str(num_objects)]['travel_time'].append(travel_time)
        shelf_stats[str(num_objects)]['path_length'].append(path_length)
        shelf_stats[str(num_objects)]['total_rrt_time'].append(total_rrt_time)
        shelf_stats[str(num_objects)]['total_coll_time'].append(total_coll_time)
        shelf_stats[str(num_objects)]['total_nn_time'].append(total_nn_time)

# %%
./sipp.exe -pnp true -mode random_search -seed 100 -robot_path  'in/husky/0/robot_path.json' -obj_path 'in/husky/0/obj_path.json' -attempt_komo false -display true -export_images false -scene_path 'in/husky/0/scene.g'
# Out:
# Объединённый файл сохранён: /home/alex/multitask/24-data-gen/result.json

# %%
 ./sipp.exe -pnp true -mode random_search -seed 100 -robot_path  'in/conveyor/0/robot_path.json' -obj_path 'in/conveyor/0/obj_path.json' -attempt_komo false -display true -export_images false -scene_path 'in/conveyor/0/scene.g'

# %%
./sipp.exe -pnp true -mode random_search -seed 100 -robot_path  'in/shelf/0/robot_path.json' -obj_path 'in/shelf/0/obj_path.json' -attempt_komo  false -display true -export_images false -scene_path 'in/shelf/0/scene.g' -obstacle_path 'in/shelf/0/obstacles_file.json'

# %%
print("Файл успешно обработан и сохранён как 'sorted_robot_plans.json'")
# Out:
# Файл успешно обработан и сохранён как 'sorted_robot_plans.json'

# %%
args['scene'],  args['obstacles'], args['objects']
# Out:
# ('in/shelf/1933/scene.g',
#  'in/shelf/1933/obstacles_file.json',
#  'in/shelf/1933/obj_path.json')

# %%
./rrt.exe -pnp true -mode random_search -seed 100 -robot_path  'in/shelf/933/robot_path.json' -obj_path 'in/shelf/1933/obj_path.json' -attempt_komo false -display false -export_images false -scene_path 'in/shelf/1933/scene.g' -obstacle_path 'in/shelf/1933/obstacles_file.json'

# %%
file_path = "/home/alex/multitask/24-data-gen/stats.json"
with open(file_path, 'w', encoding='utf-8') as json_file:
    json.dump(shelf_stats, json_file, ensure_ascii=False, indent=4)

# %%
(shelf_stats['2']['travel_time'] + shelf_stats['3']['travel_time'] + shelf_stats['4']['travel_time']).__len__(), (shelf_stats['2']['path_length'] + shelf_stats['3']['path_length'] + shelf_stats['4']['path_length']).__len__()
# Out:
# (76, 76)

# %%
plt.scatter(np.arange(len(shelf_stats['2']['travel_time'])), shelf_stats['2']['travel_time'])
plt.scatter(np.arange(len(shelf_stats['3']['travel_time'])), shelf_stats['3']['travel_time'])
plt.scatter(np.arange(len(shelf_stats['4']['travel_time'])), shelf_stats['4']['travel_time'])

# %%
d = np.array(shelf_stats['4']['travel_time'])
d[d>0].shape, d.shape
# Out:
# ((31,), (56,))

# %%
d = np.array(shelf_stats['3']['travel_time'])
d[d>0].shape, d.shape
# Out:
# ((44,), (50,))

# %%
d = np.array(shelf_stats['2']['travel_time'])
d[d>0].shape, d.shape
# Out:
# ((61,), (70,))

# %%
plt.scatter([2, 3, 4], [61/65, 44/50, 31/56])
plt.ylim(0, 1)
plt.xticks([2, 3, 4])
plt.ylabel('success rate')
plt.xlabel('number of objects')
plt.title('Shelf scene')

# %%
with open('/home/alex/multitask/24-data-gen/stats.json', 'r') as f:
    data = json.load(f)

# %%
shelf_stats = data

# %%
colors = ['#1f77b4', "#ff7f0e", '#2ca02c']
median_colors = ['#0c4d8c', '#cc6a00', '#1a7a1a']  # На 30% темнее

boxprops = dict(linestyle='-', linewidth=1.5, color='black')
whiskerprops = dict(linestyle='--', linewidth=1, color='gray')
capprops = dict(linewidth=1.5, color='black')

medianprops = [
    dict(linestyle='-', linewidth=2.5, color=median_colors[0]),
    dict(linestyle='-', linewidth=2.5, color=median_colors[1]),
    dict(linestyle='-', linewidth=2.5, color=median_colors[2])
]

plt.rcParams['axes.titlesize'] = 14  # Размер заголовка осей
plt.rcParams['axes.labelsize'] = 12  # Размер меток осей (xlabel, ylabel)
plt.rcParams['xtick.labelsize'] = 10  # Размер меток на оси X
plt.rcParams['ytick.labelsize'] = 10  # Размер меток на оси Y
plt.rcParams['legend.fontsize'] = 10  # Размер шрифта в легенде
plt.rcParams['figure.titlesize'] = 16  # Размер заголовка всей фигуры (suptitle)



plt.figure(figsize=(16, 16))


plt.subplot(221)

plt.scatter([2, 3, 4], [61/65, 44/50, 31/56])
plt.ylim(0, 1)
plt.xticks([2, 3, 4])
plt.ylabel('success rate')
plt.xlabel('number of objects')
plt.title('Shelf scene')
plt.grid()



plt.subplot(222)

d = np.array(shelf_stats['2']['total_rrt_time'])
d = d[d>0] / 1e6
data1 = list(d)

d = np.array(shelf_stats['3']['total_rrt_time'])
d = d[d>0] / 1e6
data2 = list(d)

d = np.array(shelf_stats['4']['total_rrt_time'])
d = d[d>0] / 1e6
data3 = list(d)

all_data = [data1, data2, data3]

for i, data in enumerate(all_data):
    bp = plt.boxplot(data, 
                    positions=[i+1 + 1], 
                    widths=0.6,
                    patch_artist=True,
                    boxprops=boxprops,
                    medianprops=medianprops[i],
                    whiskerprops=whiskerprops,
                    capprops=capprops)
    
    for box in bp['boxes']:
        box.set_facecolor(colors[i])
        box.set_alpha(0.7)

plt.xticks([2, 3, 4])
plt.ylabel('время работы всех планировщиков STRRT за 1 TAMP, секунды', fontsize=12)
plt.title('total_rrt_time', pad=20, fontsize=14)

plt.grid(axis='y', linestyle=':', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.xlabel('num objects')

# plt.tight_layout()
# plt.show()



plt.subplot(223)

d = np.array(shelf_stats['2']['travel_time'])
d = d[d>0]
data1 = list(d)

d = np.array(shelf_stats['3']['travel_time'])
d = d[d>0] 
data2 = list(d)

d = np.array(shelf_stats['4']['travel_time'])
d = d[d>0] 
data3 = list(d)

all_data = [data1, data2, data3]


for i, data in enumerate(all_data):
    bp = plt.boxplot(data, 
                    positions=[i+1 + 1], 
                    widths=0.6,
                    patch_artist=True,
                    boxprops=boxprops,
                    medianprops=medianprops[i],
                    whiskerprops=whiskerprops,
                    capprops=capprops)
    
    for box in bp['boxes']:
        box.set_facecolor(colors[i])
        box.set_alpha(0.7)

plt.xticks([2, 3, 4])
plt.ylabel('время в пути для всех роботов, кадры', fontsize=12)
plt.title('travel_time', pad=20, fontsize=14)
plt.xlabel('num objects')
plt.grid(axis='y', linestyle=':', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# plt.tight_layout()
# plt.show()



plt.subplot(224)

d = np.array(shelf_stats['2']['path_length'])
d = d[d>0] 
data1 = list(d)

d = np.array(shelf_stats['3']['path_length'])
d = d[d>0] 
data2 = list(d)

d = np.array(shelf_stats['4']['path_length'])
d = d[d>0] 
data3 = list(d)

all_data = [data1, data2, data3]


for i, data in enumerate(all_data):
    bp = plt.boxplot(data, 
                    positions=[i+1 + 1], 
                    widths=0.6,
                    patch_artist=True,
                    boxprops=boxprops,
                    medianprops=medianprops[i],
                    whiskerprops=whiskerprops,
                    capprops=capprops)
    
    for box in bp['boxes']:
        box.set_facecolor(colors[i])
        box.set_alpha(0.7)

plt.xticks([2, 3, 4])
plt.ylabel('длина пути всех роботов, радианы', fontsize=12)
plt.xlabel('num objects')
plt.title('path_length', pad=20, fontsize=14)

plt.grid(axis='y', linestyle=':', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# plt.tight_layout()
# plt.show()

# %%
colors = ['#1f77b4', "#ff7f0e", '#2ca02c']
median_colors = ['#0c4d8c', '#cc6a00', '#1a7a1a']  # На 30% темнее

boxprops = dict(linestyle='-', linewidth=1.5, color='black')
whiskerprops = dict(linestyle='--', linewidth=1, color='gray')
capprops = dict(linewidth=1.5, color='black')

medianprops = [
    dict(linestyle='-', linewidth=2.5, color=median_colors[0]),
    dict(linestyle='-', linewidth=2.5, color=median_colors[1]),
    dict(linestyle='-', linewidth=2.5, color=median_colors[2])
]

plt.rcParams['axes.titlesize'] = 14  # Размер заголовка осей
plt.rcParams['axes.labelsize'] = 12  # Размер меток осей (xlabel, ylabel)
plt.rcParams['xtick.labelsize'] = 10  # Размер меток на оси X
plt.rcParams['ytick.labelsize'] = 10  # Размер меток на оси Y
plt.rcParams['legend.fontsize'] = 10  # Размер шрифта в легенде
plt.rcParams['figure.titlesize'] = 16  # Размер заголовка всей фигуры (suptitle)



plt.figure(figsize=(16, 16))


plt.subplot(221)

plt.scatter([2, 3, 4], [48/50, 47/50, 42/50])
plt.ylim(0, 1)
plt.xticks([2, 3, 4])
plt.ylabel('success rate')
plt.xlabel('number of objects')
plt.title('Shelf scene')
plt.grid()



plt.subplot(222)

d = np.array(shelf_stats['2']['total_rrt_time'])
d = d[d>0] / 1e6
data1 = list(d)

d = np.array(shelf_stats['3']['total_rrt_time'])
d = d[d>0] / 1e6
data2 = list(d)

d = np.array(shelf_stats['4']['total_rrt_time'])
d = d[d>0] / 1e6
data3 = list(d)

all_data = [data_sets[0][data_sets[0] > 0.1], data_sets[1][data_sets[1] > 0.098], data_sets[2][data_sets[2] > 0.12]]

for i, data in enumerate(all_data):
    bp = plt.boxplot(data, 
                    positions=[i+1 + 1], 
                    widths=0.6,
                    patch_artist=True,
                    boxprops=boxprops,
                    medianprops=medianprops[i],
                    whiskerprops=whiskerprops,
                    capprops=capprops)
    
    for box in bp['boxes']:
        box.set_facecolor(colors[i])
        box.set_alpha(0.7)

plt.xticks([2, 3, 4])
plt.ylabel('время работы всех планировщиков STRRT за 1 TAMP, секунды', fontsize=12)
plt.title('total_rrt_time', pad=20, fontsize=14)

plt.grid(axis='y', linestyle=':', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.xlabel('num objects')

# plt.tight_layout()
# plt.show()



plt.subplot(223)

d = np.array(shelf_stats['2']['travel_time'])
d = d[d>0]
data1 = list(d)

d = np.array(shelf_stats['3']['travel_time'])
d = d[d>0] 
data2 = list(d)

d = np.array(shelf_stats['4']['travel_time'])
d = d[d>0] 
data3 = list(d)

all_data = [data_sets[3][data_sets[3] > 100], data_sets[4][data_sets[4] > 100], data_sets[5][data_sets[5] > 100]]

for i, data in enumerate(all_data):
    bp = plt.boxplot(data, 
                    positions=[i+1 + 1], 
                    widths=0.6,
                    patch_artist=True,
                    boxprops=boxprops,
                    medianprops=medianprops[i],
                    whiskerprops=whiskerprops,
                    capprops=capprops)
    
    for box in bp['boxes']:
        box.set_facecolor(colors[i])
        box.set_alpha(0.7)

plt.xticks([2, 3, 4])
plt.ylabel('время в пути для всех роботов, кадры', fontsize=12)
plt.title('travel_time', pad=20, fontsize=14)
plt.xlabel('num objects')
plt.grid(axis='y', linestyle=':', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# plt.tight_layout()
# plt.show()



plt.subplot(224)

d = np.array(shelf_stats['2']['path_length'])
d = d[d>0] 
data1 = list(d)

d = np.array(shelf_stats['3']['path_length'])
d = d[d>0] 
data2 = list(d)

d = np.array(shelf_stats['4']['path_length'])
d = d[d>0] 
data3 = list(d)

all_data = [data_sets[6][data_sets[6] > 10], data_sets[7][data_sets[7] > 5], data_sets[8][data_sets[8] > 10]]



for i, data in enumerate(all_data):
    bp = plt.boxplot(data, 
                    positions=[i+1 + 1], 
                    widths=0.6,
                    patch_artist=True,
                    boxprops=boxprops,
                    medianprops=medianprops[i],
                    whiskerprops=whiskerprops,
                    capprops=capprops)
    
    for box in bp['boxes']:
        box.set_facecolor(colors[i])
        box.set_alpha(0.7)

plt.xticks([2, 3, 4])
plt.ylabel('длина пути всех роботов, радианы', fontsize=12)
plt.xlabel('num objects')
plt.title('path_length', pad=20, fontsize=14)

plt.grid(axis='y', linestyle=':', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# plt.tight_layout()
# plt.show()

# %%
for folder in folders[:30]:
    print(get_num_obj(f'/home/alex/multitask/24-data-gen/in/shelf/{folder}/obj_path.json'), folder)
# Out:
# 4 1933
# 2 703
# 4 1178
# 4 2299
# 3 1376
# 2 1231
# 3 5041
# 2 3706
# 2 413
# 3 3219
# 2 4927
# 3 930
# 3 1393
# 2 3780
# 4 3459
# 4 1294
# 2 2737
# 3 498
# 2 632
# 2 3195
# 3 2616
# 2 4047
# 4 312
# 4 2662
# 4 3170
# 3 654
# 3 3921
# 2 190
# 2 3389
# 2 1417

# %%
folder = '190'
args = { 'robots':    f'in/shelf/{folder}/robot_path.json',
                  'objects':   f'in/shelf/{folder}/obj_path.json',
                  'scene':     f'in/shelf/{folder}/scene.g',
                  'obstacles': f'in/shelf/{folder}/obstacles_file.json'}

command = [
    './x.exe',
    '-pnp',             'true',
    '-mode',            'random_search',
    '-seed',            '879',
    '-robot_path',      args['robots'],
    '-obj_path',        args['objects'],
    '-attempt_komo',    'false',
    '-display',         'true',
    '-export_images',   'true',
    '-scene_path',      args['scene'],
    '-obstacle_path',   args['obstacles']
]
validate_data(args)
subprocess.run(command)

# %%
print(*command)
# Out:
# ./x.exe -pnp true -mode random_search -seed 879 -robot_path in/shelf/190/robot_path.json -obj_path in/shelf/190/obj_path.json -attempt_komo false -display true -export_images true -scene_path in/shelf/190/scene.g -obstacle_path in/shelf/190/obstacles_file.json

# %%
ffmpeg -framerate 30 -pattern_type glob -i "*.ppm" -c:v libx264  -pix_fmt yuv444p -crf 0 -preset veryslow -tune film -x264-params "ref=16:me=umh:subme=11:trellis=2"  output_lossless.mp4
